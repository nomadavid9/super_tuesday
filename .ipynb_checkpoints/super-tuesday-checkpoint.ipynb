# %% [markdown]
# The Democrats have a proportional system: Candidates get delegates in proportion to their vote share in a state’s primary or caucus.

# %%
AL = {'state': 'Alabama',
'primary_or_caucus':'primary',
      'primary_type':'open',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
      'congressional_districts': 7,
       'total_delegates': 52,
       'district_delegates': 34, 
       'pledged_delegates': 18,
       'pleo_delegates': 7,
       'at_large_delegates': 11,
       'allocation_rules': '''34 district delegates are to be allocated proportionally to presidential contenders based on the primary results in each of the State's congressional districts.
18 delegates are to be allocated to presidential contenders based on the primary vote statewide.'''
}

# %%
AK = {'state': 'Alaska',
'primary_or_caucus':'primary',
      'primary_type':'closed',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
      'congressional_districts': 1,
      'total_delegates': 14,
       'district_delegates': 9, 
       'pledged_delegates': 5,
       'pleo_delegates': 2,
       'at_large_delegates': 3,
       'allocation_rules': '''9 National Convention District delegates are pledged to presidential contenders in proportion to the percentage of support each candidate receives in the party-run primary as a whole. Alaska has one Congressional District. A mandatory 15 percent threshold is required for such allocations.
5 National Convention statewide delegates are pledged to presidential contenders in proportion to the percentage of support each candidate receives in the party-run primary as a whole. A mandatory 15 percent threshold is required for such allocations.'''
}

# %%
AS = {'state': 'American Samoa',
'primary_or_caucus':'caucus',
      'primary_type':'open',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
      'congressional_districts': 0,
      'total_delegates': 6,
       'district_delegates': 0, 
       'pledged_delegates': 6,
       'pleo_delegates': 0,
       'at_large_delegates': 6,
       'allocation_rules': '''6 delegates are to be pledged to presidential contenders based on the Territorial Caucus vote island-wide.'''
}

# %%
AR = {'state': 'Arkansas',
'primary_or_caucus':'primary',
      'primary_type':'open',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
      'congressional_districts': 4, 
       'total_delegates': 31,
       'district_delegates': 20, 
       'pledged_delegates': 11,
       'pleo_delegates': 4,
       'at_large_delegates': 7,
       'allocation_rules': '''20 district delegates are to be allocated proportionally to presidential contenders based on the primary results in each of the State's 4 congressional districts.
                              11 delegates are to be allocated to presidential contenders based on the primary vote statewide.'''
}

# %%
CA = {'state': 'California',
'primary_or_caucus':'primary',
      'primary_type':'modified',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
      'congressional_districts': 53,
       'total_delegates': 416,
       'district_delegates': 272, 
       'pledged_delegates': 144,
       'pleo_delegates': 54,
       'at_large_delegates': 90,
       'allocation_rules': '''272 district delegates are to be pledged 
                            proportionally to presidential contenders 
                            based on the primary results in each of the 
                            State's 53 congressional districts. 
                            Remaining 144 delegates are to be pledged to 
                            presidential contenders based on the primary 
                            vote statewide.'''
}

# %%
CO = {'state': 'Colorado',
'primary_or_caucus':'primary',
      'primary_type':'modified',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
      'congressional_districts': 7,
       'total_delegates': 67,
       'district_delegates': 44, 
       'pledged_delegates': 23,
       'pleo_delegates': 9,
       'at_large_delegates': 14,
       'allocation_rules': '''44 district delegates are to be pledged proportionally to presidential contenders based on the primary results in each of the State's 7 congressional districts.
                              23 delegates are to be pledged to presidential contenders based on the primary vote statewide.'''
}

# %%
DA = {'state': 'Democrats Abroad',
'primary_or_caucus':'caucus',
      'primary_type':'open',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
      'congressional_districts': 0, 
       'total_delegates': 13,
       'district_delegates': 0, 
       'pledged_delegates': 13,
       'pleo_delegates': 1,
       'at_large_delegates': 12,
       'allocation_rules': '''13  delegates are to be allocated to presidential contenders based on the global primary vote as a whole.'''
}

# %%
ME = {'state': 'Maine',
'primary_or_caucus':'primary',
      'primary_type':'closed',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
      'congressional_districts': 2,
       'total_delegates': 24,
       'district_delegates': 16, 
       'pledged_delegates': 8,
       'pleo_delegates': 3,
       'at_large_delegates': 5,
       'allocation_rules': '''16 district delegates are to be allocated proportionally based on the presidential preferences expressed in each of the State's 2 congressional districts.
                              8 delegates are to be allocated to presidential contenders based the support for the presidential contenders in the state as a whole.'''
}

# %%
MA = {'state': 'Massachusetts',
'primary_or_caucus':'primary',
      'primary_type':'modified',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
      'congressional_districts': 9,
       'total_delegates': 91,
       'district_delegates': 59, 
       'pledged_delegates': 32,
       'pleo_delegates': 12,
       'at_large_delegates': 20,
       'allocation_rules': '''59 district delegates are to be allocated proportionally to presidential contenders based on the primary results in each of the State's 9 congressional districts.
32 delegates are to be allocated to presidential contenders based on the primary vote statewide.'''
}

# %%
MN = {'state': 'Minnesota',
'primary_or_caucus':'primary',
      'primary_type':'closed',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
      'congressional_districts': 8,
       'total_delegates': 75,
       'district_delegates': 49, 
       'pledged_delegates': 26,
       'pleo_delegates': 10,
       'at_large_delegates': 16,
       'allocation_rules': '''49 district delegates are to be pledged proportionally to presidential contenders based on the results from the primary in each of the State's 8 congressional districts.
In addition, 26 delegates are to be pledged to presidential contenders based statewide results of the primary.'''
}

# %%
NC = {'state': 'North Carolina',
'primary_or_caucus':'primary',
      'primary_type':'modified',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
      'congressional_districts': 13,
       'total_delegates': 110,
       'district_delegates': 72, 
       'pledged_delegates': 38,
       'pleo_delegates': 14,
       'at_large_delegates': 24,
       'allocation_rules': '''72 district delegates are to be pledged proportionally to presidential contenders based on the primary results in each of the State's 13 congressional districts.
In addition, 38 delegates are to be allocated to presidential contenders based on the primary vote statewide.'''
}

# %%
OK = {'state': 'Oklahoma',
      'primary_or_caucus':'primary',
      'primary_type':'modified',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
       'congressional_districts': 2,
       'total_delegates': 91,
       'district_delegates': 59, 
       'pledged_delegates': 32,
       'pleo_delegates': 12,
       'at_large_delegates': 20,      
       'allocation_rules': '''59 district delegates are to be allocated proportionally to presidential contenders based on the primary results in each of the State's 9 congressional districts.
32 delegates are to be allocated to presidential contenders based on the primary vote statewide.'''
}

# %%
TN = {'state': 'Tennessee',
      'primary_or_caucus':'primary',
      'primary_type':'open',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
       'congressional_districts': 9,
       'total_delegates': 64,
       'district_delegates': 42, 
       'pledged_delegates': 22,
       'pleo_delegates': 8,
       'at_large_delegates': 14,      
       'allocation_rules': '''42 district delegates are to be pledged proportionally to presidential contenders based on the primary results in each of the State's congressional districts.
In addition, 22 delegates are to be pledged to presidential contenders based on the primary vote statewide.'''
}

# %%
TX = {'state': 'Texas',
      'primary_or_caucus':'primary',
      'primary_type':'closed',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
       'congressional_districts': 31,
       'total_delegates': 228,
       'district_delegates': 149, 
       'pledged_delegates': 79,
       'pleo_delegates': 30,
       'at_large_delegates': 49,      
       'allocation_rules': '''149 district delegates are to be pledged proportionally to presidential contenders based on the primary results 
                               in each of the State's 31 Senatorial Districts. Texas has 149 district delegates apportioned
                               among its 31 STATE SENATORIAL DISTRICTS [unlike most states- as well as the Texas Republican Party-
                               Texas Democrats are NOT using the state's Congressional Districts as a basis of
                               National Convention delegate allocation] as follows: (SD= "Senatorial District")].
                               79 delegates are to be pledged to presidential contenders based on the primary vote statewide.'''
}
# Texas allocates accross state senatorial districts

# %%
UT = {'state': 'Utah',
      'primary_or_caucus':'primary',
      'primary_type':'closed',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
       'congressional_districts': 4,
       'total_delegates': 29,
       'district_delegates': 19, 
       'pledged_delegates': 10,
       'pleo_delegates': 4,
       'at_large_delegates': 6,      
       'allocation_rules': '''19 district delegates are to be allocated proportionally to presidential contenders based on the primary results in each of the State's 4 congressional districts.
10 delegates are to be allocated to presidential contenders based on the primary vote statewide.'''
}

# %%
VT = {'state': 'Vermont',
      'primary_or_caucus':'primary',
      'primary_type':'open',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
       'congressional_districts': 1,
       'total_delegates': 16,
       'district_delegates': 11, 
       'pledged_delegates': 5,
       'pleo_delegates': 2,
       'at_large_delegates': 3,      
       'allocation_rules': '''11 district delegates are to be pledged proportionally to presidential contenders based on the statewide primary results as Vermont has only one Congressional District.
In addition, 5 delegates are to be pledged to presidential contenders based on the primary vote statewide.'''
}

# %%
VA = {'state': 'Virginia',
      'primary_or_caucus':'primary',
      'primary_type':'open',
      'mandatory_threshold': '15%',
       'Delegate Binding':'proportional',
       'congressional_districts': 11,
       'total_delegates': 99,
       'district_delegates': 65, 
       'pledged_delegates': 34,
       'pleo_delegates': 13,
       'at_large_delegates': 21,      
       'allocation_rules': '''65 district delegates are to be allocated proportionally to presidential contenders based on the primary results in each of the State's 11 congressional districts.
34 delegates are to be pledged to presidential contenders based on the primary results statewide.'''
}

# %%
super_tuesday_states = {'Alabama':AL, 
                        'Alaska':AK, 
                        'American Samoa':AS, 
                        'Arkansas':AR,
                        'California':CA, 
                        'Colorado':CO, 
                        'Democrats Abroad':DA,
                        'Maine':ME, 
                        'Massachusetts':MA, 
                        'Minnesota':MN,
                        'North Carolina':NC, 
                        'Oklahoma':OK, 
                        'Tennessee':TN,
                        'Texas':TX, 
                        'Utah':UT, 
                        'Vermont':VT, 
                        'Virginia':VA}

# %%
import pandas as pd

# %%
super_tuesday = pd.DataFrame(list(super_tuesday_states.values()))

# %%
super_tuesday = super_tuesday[['state', 'primary_type', 'primary_or_caucus', 
       'Delegate Binding', 'congressional_districts', 'total_delegates',
       'district_delegates', 'pledged_delegates', 'pleo_delegates',
       'at_large_delegates', 'mandatory_threshold', 'allocation_rules']]

# %%
super_tuesday.columns = ['state', 'primary_type', 'primary_or_caucus', 
       'delegate_binding', 'num_congressional_districts', 'total_delegates',
       'num_district_delegates', 'total_pledged_delegates', 'num_pleo_delegates',
       'num_at_large_delegates', 'mandatory_threshold', 'allocation_rules']

# %%
super_tuesday = super_tuesday.sort_values(by='state')

# %%
super_tuesday
# Out:
#                state primary_type primary_or_caucus delegate_binding  \
# 0            Alabama         open           primary     proportional
# 1             Alaska       closed           primary     proportional
# 2     American Samoa         open            caucus     proportional
# 3           Arkansas         open           primary     proportional
# 4         California     modified           primary     proportional
# 5           Colorado     modified           primary     proportional
# 6   Democrats Abroad         open            caucus     proportional
# 7              Maine       closed           primary     proportional
# 8      Massachusetts     modified           primary     proportional
# 9          Minnesota       closed           primary     proportional
# 10    North Carolina     modified           primary     proportional
# 11          Oklahoma     modified           primary     proportional
# 12         Tennessee         open           primary     proportional
# ...

# %%
super_tuesday.to_csv('super_tuesday_delegate_allocation.csv', index=None)
